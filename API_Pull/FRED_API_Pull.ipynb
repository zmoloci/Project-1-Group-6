# %%
# Dependencies
import requests
from config import api_key
from config import fred_api
from pprint import pprint
import numpy as np
import pandas as pd

from full_fred.fred import Fred

url = "https://api.stlouisfed.org/fred/data?api_key=d6c9f833698c931c8e63dd3973b55579&category?category_id="

fred = Fred('key.txt')

per_capita_inc_indexes = np.arange(0,124)

# Personal Income in Albany County, NY Example
fred.get_series_df('PI36001')



# DOESN'T WORK #
# for indexes in per_capita_inc_indexes:
#     if len(str(indexes)) < 2:
#         index = f'PI3600{indexes}'
#         print(index)
#     elif len(str(indexes)) < 3:
#         index = f'PI360{indexes}'
#         print(index)
#     else:
#         index = f'PI36{indexes}'
#         print(index)
#     try:
#         fred.get_series_df(index)
#     except:
#         print('No Record')

# Drop first two columns and then add a column for County Name
# Iterate through index values - match county names (alphabetical?)
# or Scrape county names from website - iterate urls as you iterate through index (index is part of url)
# Out:
#    realtime_start realtime_end        date     value
# 0      2023-02-09   2023-02-09  1969-01-01   5313763
# 1      2023-02-09   2023-02-09  1970-01-01   5657441
# 2      2023-02-09   2023-02-09  1971-01-01   5908732
# 3      2023-02-09   2023-02-09  1972-01-01   6182516
# 4      2023-02-09   2023-02-09  1973-01-01   6381338
# 5      2023-02-09   2023-02-09  1974-01-01   6760973
# 6      2023-02-09   2023-02-09  1975-01-01   7242870
# 7      2023-02-09   2023-02-09  1976-01-01   7401039
# 8      2023-02-09   2023-02-09  1977-01-01   7680066
# 9      2023-02-09   2023-02-09  1978-01-01   8077084
# 10     2023-02-09   2023-02-09  1979-01-01   8585673
# 11     2023-02-09   2023-02-09  1980-01-01   9495519
# 12     2023-02-09   2023-02-09  1981-01-01  10547807
# 13     2023-02-09   2023-02-09  1982-01-01  11439640
# 14     2023-02-09   2023-02-09  1983-01-01  12208651
# 15     2023-02-09   2023-02-09  1984-01-01  13305682
# 16     2023-02-09   2023-02-09  1985-01-01  14035459
# 17     2023-02-09   2023-02-09  1986-01-01  14825827
# 18     2023-02-09   2023-02-09  1987-01-01  15425540
# 19     2023-02-09   2023-02-09  1988-01-01  16445220
# 20     2023-02-09   2023-02-09  1989-01-01  17574568
# 21     2023-02-09   2023-02-09  1990-01-01  18881470
# 22     2023-02-09   2023-02-09  1991-01-01  19195347
# 23     2023-02-09   2023-02-09  1992-01-01  19716168
# 24     2023-02-09   2023-02-09  1993-01-01  20244960
# 25     2023-02-09   2023-02-09  1994-01-01  20961426
# 26     2023-02-09   2023-02-09  1995-01-01  21736830
# 27     2023-02-09   2023-02-09  1996-01-01  22438520
# 28     2023-02-09   2023-02-09  1997-01-01  23082115
# 29     2023-02-09   2023-02-09  1998-01-01  23881821
# 30     2023-02-09   2023-02-09  1999-01-01  25012469
# 31     2023-02-09   2023-02-09  2000-01-01  26822840
# 32     2023-02-09   2023-02-09  2001-01-01  29074144
# 33     2023-02-09   2023-02-09  2002-01-01  29716871
# 34     2023-02-09   2023-02-09  2003-01-01  30658414
# 35     2023-02-09   2023-02-09  2004-01-01  32305263
# 36     2023-02-09   2023-02-09  2005-01-01  32612817
# 37     2023-02-09   2023-02-09  2006-01-01  34970066
# 38     2023-02-09   2023-02-09  2007-01-01  37943366
# 39     2023-02-09   2023-02-09  2008-01-01  37981301
# 40     2023-02-09   2023-02-09  2009-01-01  38731918
# 41     2023-02-09   2023-02-09  2010-01-01  40361109
# 42     2023-02-09   2023-02-09  2011-01-01  41297118
# 43     2023-02-09   2023-02-09  2012-01-01  41509621
# 44     2023-02-09   2023-02-09  2013-01-01  42086769
# 45     2023-02-09   2023-02-09  2014-01-01  43733380
# 46     2023-02-09   2023-02-09  2015-01-01  45807957
# 47     2023-02-09   2023-02-09  2016-01-01  46919572
# 48     2023-02-09   2023-02-09  2017-01-01  49762632
# 49     2023-02-09   2023-02-09  2018-01-01  51250251
# 50     2023-02-09   2023-02-09  2019-01-01  54854029
# 51     2023-02-09   2023-02-09  2020-01-01  62197095
# 52     2023-02-09   2023-02-09  2021-01-01  66735687

# %%
category_id = "0"

query_url = f'{url}{category_id}&api_key={fred_api}&file_type=json'

# %%
ny_fred = requests.get(query_url).json()

pprint(ny_fred)
print(query_url)
# Out:
# {'categories': [{'id': 0, 'name': 'Categories', 'parent_id': 0}]}
# https://api.stlouisfed.org/fred/category?category_id=0&api_key=d6c9f833698c931c8e63dd3973b55579&file_type=json

# %%
categories = []

category_id = "0"

for i in range(1000):
    category_id = i
    query_url = f'{url}{category_id}&api_key={fred_api}&file_type=json'
    ny_fred = requests.get(query_url).json()
    pprint(ny_fred)
# Out:
# {'categories': [{'id': 0, 'name': 'Categories', 'parent_id': 0}]}
# {'categories': [{'id': 1,
#                  'name': 'Production & Business Activity',
#                  'parent_id': 0}]}
# {'categories': [{'id': 2, 'name': 'Productivity & Costs', 'parent_id': 10}]}
# {'categories': [{'id': 3,
#                  'name': 'Industrial Production & Capacity Utilization',
#                  'parent_id': 1}]}
# {'categories': [{'id': 4, 'name': 'Employment Cost Index', 'parent_id': 32455}]}
# {'categories': [{'id': 5,
#                  'name': 'Federal Government Debt',
#                  'parent_id': 32992}]}
# {'categories': [{'id': 6, 'name': 'Retail Trade', 'parent_id': 1}]}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'categories': [{'id': 9,
#                  'name': 'Consumer Price Indexes (CPI and PCE)',
#                  'parent_id': 32455}]}
# {'categories': [{'id': 10,
#                  'name': 'Population, Employment, & Labor Markets',
#                  'parent_id': 0}]}
# {'categories': [{'id': 11,
#                  'name': 'Current Employment Statistics (Establishment Survey)',
#                  'notes': 'The establishment survey provides data on '
#                           'employment, hours, and earnings by industry.\r\n'
#                           'Numerous conceptual and methodological differences '
#                           'between the current population (household) and '
#                           'establishment surveys result in important '
#                           'distinctions in the employment estimates derived '
#                           'from the surveys. Among these are: \r\n'
#                           'The household survey includes agricultural workers, '
#                           'the self- employed, unpaid family workers, and '
#                           'private household workers among the employed. These '
#                           'groups are excluded from the establishment '
#                           'survey. \r\n'
#                           'The household survey includes people on unpaid '
#                           'leave among the employed. The establishment survey '
#                           'does not. \r\n'
#                           'The household survey is limited to workers 16 years '
#                           'of age and older. The establishment survey is not '
#                           'limited by age. \r\n'
#                           'The household survey has no duplication of '
#                           'individuals, because individuals are counted only '
#                           'once, even if they hold more than one job. In the '
#                           'establishment survey, employees working at more '
#                           'than one job and thus appearing on more than one '
#                           'payroll are counted separately for each '
#                           'appearance. \r\n'
#                           'For more information, visit '
#                           'http://www.bls.gov/news.release/empsit.tn.htm.',
#                  'parent_id': 10}]}
# {'categories': [{'id': 12,
#                  'name': 'Current Population Survey (Household Survey)',
#                  'notes': 'The Current Population Survey (Household Survey) is '
#                           'a monthly survey of households conducted by the '
#                           'Bureau of Labor Statistics. It provides a '
#                           'comprehensive body of data on the labor force, '
#                           'employment, unemployment, persons not in the labor '
#                           'force, hours of work, earnings, and other '
#                           'demographic and labor force characteristics. \r\n'
#                           'Numerous conceptual and methodological differences '
#                           'between the current population (household) and '
#                           'establishment surveys result in important '
#                           'distinctions in the employment estimates derived '
#                           'from the surveys. Among these are: \r\n'
#                           'The household survey includes agricultural workers, '
#                           'the self- employed, unpaid family workers, and '
#                           'private household workers among the employed. These '
#                           'groups are excluded from the establishment '
#                           'survey. \r\n'
#                           'The household survey includes people on unpaid '
#                           'leave among the employed. The establishment survey '
#                           'does not. \r\n'
#                           'The household survey is limited to workers 16 years '
#                           'of age and older. The establishment survey is not '
#                           'limited by age. \r\n'
#                           'The household survey has no duplication of '
#                           'individuals, because individuals are counted only '
#                           'once, even if they hold more than one job. In the '
#                           'establishment survey, employees working at more '
#                           'than one job and thus appearing on more than one '
#                           'payroll are counted separately for each '
#                           'appearance. \r\n'
#                           '\r\n'
#                           'For more information, visit '
#                           'http://www.bls.gov/news.release/empsit.tn.htm.',
#                  'parent_id': 10}]}
# {'categories': [{'id': 13,
#                  'name': 'U.S. Trade & International Transactions',
#                  'parent_id': 32992}]}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'categories': [{'id': 15, 'name': 'Exchange Rates', 'parent_id': 32991}]}
# {'categories': [{'id': 16, 'name': 'Exports', 'parent_id': 13}]}
# {'categories': [{'id': 17, 'name': 'Imports', 'parent_id': 13}]}
# {'categories': [{'id': 18,
#                  'name': 'National Income & Product Accounts',
#                  'parent_id': 32992}]}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'categories': [{'id': 21,
#                  'name': 'Price Indexes & Deflators',
#                  'parent_id': 18}]}
# {'categories': [{'id': 22, 'name': 'Interest Rates', 'parent_id': 32991}]}
# {'categories': [{'id': 23, 'name': 'Banking', 'parent_id': 32991}]}
# {'categories': [{'id': 24, 'name': 'Monetary Data', 'parent_id': 32991}]}
# {'categories': [{'id': 25, 'name': 'M1 and Components', 'parent_id': 24}]}
# {'categories': [{'id': 26, 'name': 'Memorandum Items', 'parent_id': 24}]}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'categories': [{'id': 28, 'name': 'M3 and Components', 'parent_id': 24}]}
# {'categories': [{'id': 29, 'name': 'M2 and Components', 'parent_id': 24}]}
# {'categories': [{'id': 30, 'name': 'MZM', 'parent_id': 24}]}
# {'categories': [{'id': 31,
#                  'name': 'Producer Price Indexes (PPI)',
#                  'parent_id': 32455}]}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'categories': [{'id': 46, 'name': 'Financial Indicators', 'parent_id': 32991}]}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'categories': [{'id': 51, 'name': 'Bankers Acceptance Rate', 'parent_id': 22}]}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'categories': [{'id': 64,
#                  'name': '8th District Banking Performance',
#                  'parent_id': 23}]}
# {'categories': [{'id': 65, 'name': 'Arkansas', 'parent_id': 64}]}
# {'categories': [{'id': 66, 'name': 'Illinois', 'parent_id': 64}]}
# {'categories': [{'id': 67, 'name': 'Indiana', 'parent_id': 64}]}
# {'categories': [{'id': 68, 'name': 'Kentucky', 'parent_id': 64}]}
# {'categories': [{'id': 69, 'name': 'Mississippi', 'parent_id': 64}]}
# {'categories': [{'id': 70, 'name': 'Missouri', 'parent_id': 64}]}
# {'categories': [{'id': 71, 'name': 'Tennessee', 'parent_id': 64}]}
# {'categories': [{'id': 72, 'name': '8th District', 'parent_id': 64}]}
# {'categories': [{'id': 73, 'name': 'United States', 'parent_id': 64}]}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'categories': [{'id': 82,
#                  'name': 'Treasury Inflation-Indexed Securities',
#                  'parent_id': 22}]}
# {'categories': [{'id': 83,
#                  'name': 'Condition of Banks',
#                  'notes': 'For census division definitions, see '
#                           'http://research.stlouisfed.org/fred2/censusdivisions.',
#                  'parent_id': 23}]}
# {'categories': [{'id': 84,
#                  'name': 'New England Census Division',
#                  'notes': 'For census division definitions, see '
#                           'http://research.stlouisfed.org/fred2/censusdivisions.',
#                  'parent_id': 83}]}
# {'categories': [{'id': 85,
#                  'name': 'Middle Atlantic Census Division',
#                  'notes': 'For census division definitions, see '
#                           'http://research.stlouisfed.org/fred2/censusdivisions.',
#                  'parent_id': 83}]}
# {'categories': [{'id': 86,
#                  'name': 'East North Central Census Division',
#                  'notes': 'For census division definitions, see '
#                           'http://research.stlouisfed.org/fred2/censusdivisions.',
#                  'parent_id': 83}]}
# {'categories': [{'id': 87,
#                  'name': 'West North Central Census Division',
#                  'notes': 'For census division definitions, see '
#                           'http://research.stlouisfed.org/fred2/censusdivisions.',
#                  'parent_id': 83}]}
# {'categories': [{'id': 88,
#                  'name': 'South Atlantic Census Division',
#                  'notes': 'For census division definitions, see '
#                           'http://research.stlouisfed.org/fred2/censusdivisions.',
#                  'parent_id': 83}]}
# {'categories': [{'id': 89,
#                  'name': 'East South Central Census Division',
#                  'notes': 'For census division definitions, see '
#                           'http://research.stlouisfed.org/fred2/censusdivisions.',
#                  'parent_id': 83}]}
# {'categories': [{'id': 90,
#                  'name': 'West South Central Census Division',
#                  'notes': 'For census division definitions, see '
#                           'http://research.stlouisfed.org/fred2/censusdivisions.',
#                  'parent_id': 83}]}
# {'categories': [{'id': 91,
#                  'name': 'Mountain Census Division',
#                  'notes': 'For census division definitions, see '
#                           'http://research.stlouisfed.org/fred2/censusdivisions.',
#                  'parent_id': 83}]}
# {'categories': [{'id': 92,
#                  'name': 'Pacific Census Division',
#                  'notes': 'For census division definitions, see '
#                           'http://research.stlouisfed.org/fred2/censusdivisions.',
#                  'parent_id': 83}]}
# {'categories': [{'id': 93, 'name': 'United States', 'parent_id': 83}]}
# {'categories': [{'id': 94,
#                  'name': 'Daily Rates',
#                  'notes': 'Effective January 1, 2009, the Federal Reserve '
#                           'Board discontinued publication of the H.10 Daily '
#                           'Update, which provided U.S. dollar exchange rates '
#                           'against other currencies certified for customs '
#                           'purposes by the Federal Reserve Bank of New York '
#                           'and summary measures of the foreign exchange value '
#                           'of the dollar.   \r\n'
#                           ' The Federal Reserve Board still makes the '
#                           'certified exchange rates available.  Effective '
#                           'January 5, 2009, the Board publishes the daily '
#                           'exchange rate data in a weekly version of the H.10 '
#                           'release.\r\n'
#                           ' As a result, the daily exchange rates in the FRED '
#                           'database will be updated once each week to capture '
#                           'the daily data from the previous week.',
#                  'parent_id': 15}]}
# {'categories': [{'id': 95, 'name': 'Monthly Rates', 'parent_id': 15}]}
# {'categories': [{'id': 96,
#                  'name': 'M2 Minus Small Time Deposits',
#                  'parent_id': 24}]}
# {'categories': [{'id': 97, 'name': 'Housing', 'parent_id': 1}]}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'categories': [{'id': 99,
#                  'name': 'Securities & Investments',
#                  'parent_id': 23}]}
# {'categories': [{'id': 100, 'name': 'Commercial Banking', 'parent_id': 23}]}
# {'categories': [{'id': 101, 'name': 'Consumer Credit', 'parent_id': 23}]}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'categories': [{'id': 104, 'name': 'Population', 'parent_id': 10}]}
# {'categories': [{'id': 105, 'name': 'Trade-Weighted Indexes', 'parent_id': 15}]}
# {'categories': [{'id': 106, 'name': 'GDP/GNP', 'parent_id': 18}]}
# {'categories': [{'id': 107,
#                  'name': "Gov't Receipts, Expenditures & Investment",
#                  'parent_id': 18}]}
# {'categories': [{'id': 108, 'name': 'Foreign Transactions', 'parent_id': 18}]}
# {'categories': [{'id': 109,
#                  'name': 'Private Enterprise Income',
#                  'parent_id': 18}]}
# {'categories': [{'id': 110,
#                  'name': 'Personal Income & Outlays',
#                  'parent_id': 18}]}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'categories': [{'id': 112,
#                  'name': 'Domestic Capital Account (Saving & Investment)',
#                  'parent_id': 18}]}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'categories': [{'id': 114, 'name': 'Mortgage Rates', 'parent_id': 22}]}
# {'categories': [{'id': 115,
#                  'name': 'Treasury Constant Maturity',
#                  'parent_id': 22}]}
# {'categories': [{'id': 116, 'name': 'Treasury Bills', 'parent_id': 22}]}
# {'categories': [{'id': 117, 'name': 'Prime Bank Loan Rate', 'parent_id': 22}]}
# {'categories': [{'id': 118,
#                  'name': 'FRB Rates - discount, fed funds, primary credit',
#                  'parent_id': 22}]}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 429, 'error_message': 'Too Many Requests.  Exceeded Rate Limit'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'categories': [{'id': 191, 'name': 'United Kingdom', 'parent_id': 158}]}
# {'categories': [{'id': 192, 'name': 'Venezuela', 'parent_id': 158}]}
# {'categories': [{'id': 193, 'name': 'Tennessee', 'parent_id': 27281}]}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# {'error_code': 400,
#  'error_message': 'Bad Request.  The category does not exist.'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/1h/kbzsd68d1ql5k8k60_bnktmm0000gn/T/ipykernel_17578/2567831442.py in <module>
#       6     category_id = i
#       7     query_url = f'{url}{category_id}&api_key={fred_api}&file_type=json'
# ----> 8     ny_fred = requests.get(query_url).json()
#       9     pprint(ny_fred)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     497                     decode_content=False,
#     498                     retries=self.max_retries,
# --> 499                     timeout=timeout,
#     500                 )
#     501
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     708                 body=body,
#     709                 headers=headers,
# --> 710                 chunked=chunked,
#     711             )
#     712
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384         # Trigger any extra validation we need to do.
#     385         try:
# --> 386             self._validate_conn(conn)
#     387         except (SocketTimeout, BaseSSLError) as e:
#     388             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1040         # Force connect early to allow us to validate the connection.
#    1041         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042             conn.connect()
#    1043
#    1044         if not conn.is_verified:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     422             server_hostname=server_hostname,
#     423             ssl_context=context,
# --> 424             tls_in_tls=tls_in_tls,
#     425         )
#     426
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     400     if ca_certs or ca_cert_dir or ca_cert_data:
#     401         try:
# --> 402             context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     403         except (IOError, OSError) as e:
#     404             raise SSLError(e)
#
# KeyboardInterrupt:
